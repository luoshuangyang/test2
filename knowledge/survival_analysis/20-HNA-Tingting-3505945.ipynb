# %%
from __future__ import unicode_literals

import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import font_manager
from matplotlib.font_manager import FontProperties 

font = FontProperties(fname=r"/root/anaconda2/envs/python3/lib/python3.6/site-packages/matplotlib/mpl-data/fonts/ttf/msyh.ttf")

import numpy as np
import scipy.stats as s

# %%
data1 = pd.read_csv("3505945.csv", encoding = "GB2312")
data1
# Out:
#       机型     制造序列号    机号    参考类型                        件号                序号  \
# 0    73N  73N02373  5346  DE      3505945-12                GRTF0394
# 1    73N  73N06025  7988  DE      3505945-11                GRTA4105C
# 2    73N  73N03344  5520  DE      3505945-12                GRTF7196
# 3    73N  73N04716  5855  DE      3505945-12                GRTA9007
# 4    73N  73N04904  5823  DE      3505945-12                GRTF7419
# 5    73N  73N02648  5375  DE      3505945-12                GRTF3827
# 6    73N  73N02831  5429  DE      3505945-12                GRTA2873C
# 7    73N  73N04596  5798  DE      3505945-12                GRTF9210
# 8    73N  73N03713  5581  DE      3505945-12                GRTF5551
# 9    73N  73N03186  5503  DE      3505945-12                GRTF6111
# 10   73N  73N00607  2651  DE      3505945-12                GRTF3253
# 11   73N  73N03299  5735  DE      3505945-12                GRTF0604
# ...

# %%
data1["部件本次装机使用小时"] = data1["部件本次装机使用小时"].str.split(':').str[0].astype(int)
data_h=data1[data1["拆换原因"]=="FAIL  "]
data_h=data_h[data_h["部件装上使用循环数"]==0]
data_h["部件本次装机使用小时"].hist(bins=9, range=(0,20000))

# %%
plt.scatter(data_h.index,data_h["部件本次装机使用小时"])

# %% [markdown]
# ### Minitab Weibul function

# %%
print (data_h["部件本次装机使用小时"].min())
print (data_h["部件本次装机使用小时"].max())
# Out:
# 11
# 20627

# %%
params1 = s.dweibull.fit(data_h["部件本次装机使用小时"])
params2 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=6000)
params3 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=6500)
params4 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=7000)
params5 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=7500)
params6 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0)
params7 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=8000)
params8 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=8500)
params9 = s.dweibull.fit(data_h["部件本次装机使用小时"], floc=0, fscale=6000)
print (params1)
print (params2)
print (params3)
print (params4)
print (params5)
print (params6)
print (params7)
print (params8)
print (params9)

ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params1[0], loc=0), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]

plt.tight_layout()
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(0.1), plot=plt)
print (res1[1])
res0[1]=res1[1][2]
plt.tight_layout()

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(0.5), plot=plt)
print (res1[1])
res0[2]=res1[1][2]

plt.tight_layout()
ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(1), plot=plt)
print (res1[1])
res0[3]=res1[1][2]
plt.tight_layout()
ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(1.5), plot=plt)
print (res1[1])
res0[4]=res1[1][2]
plt.tight_layout()
ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(2), plot=plt)
print (res1[1])
res0[5]=res1[1][2]
plt.tight_layout()
ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(2.5), plot=plt)
print (res1[1])
res0[6]=res1[1][2]
plt.tight_layout()
ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(3), plot=plt)
print (res1[1])
res0[7]=res1[1][2]
plt.tight_layout()
ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(3.5), plot=plt)
print (res1[1])
res0[8]=res1[1][2]
plt.tight_layout()
fig = plt.figure()
ax = fig.add_subplot(111)
s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(3.5), plot=plt, rvalue=False)
# plt.plot(res0)
plt.show()
# Out:
# (1.384202850785695, 5051.111642014693, 6652.205261272384)
# (0.5182617187499996, 0, 6000)
# (0.5172851562499996, 0, 6500)
# (0.5154296874999995, 0, 7000)
# (0.5127929687499995, 0, 7500)
# (0.5057199412471121, 0, 4022.4902673566576)
# (0.5096679687499994, 0, 8000)
# (0.5061523437499995, 0, 8500)
# (0.5182617187499996, 0, 6000)
# (6367.66491151459, 6607.407407407407, 0.90889466926044)
# (0.19112158898368217, 6607.407407407408, 0.39135095648339296)
# (1824.8672655033, 6607.407407407407, 0.7068989011392056)
# (5196.244364405734, 6607.407407407407, 0.8733992896551902)
# (6573.351839151659, 6607.407407407407, 0.9135826735143098)
# (7055.464162722991, 6607.407407407407, 0.9199482571829486)
# (7207.308747830376, 6607.407407407407, 0.9166489207258448)
# (7232.323113513425, 6607.407407407407, 0.910708957140904)
# (7207.228106668855, 6607.407407407407, 0.9043785057790935)

# %% [markdown]
# ### Minitab 3 parameter weibull

# %%
params1 = s.dweibull.fit(data_h["部件本次装机使用小时"])
params2 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=6000)
params3 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=6500)
params4 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=7000)
params5 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=7500)
params6 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=7800)
params7 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=8000)
params8 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=8500)
params9 = s.dweibull.fit(data_h["部件本次装机使用小时"], fscale=6000)
print (params1)
print (params2)
print (params3)
print (params4)
print (params5)
print (params6)
print (params7)
print (params8)
print (params9)

ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params1[0]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params2[0]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params3[0]), plot=plt)
print (res1[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params4[0]), plot=plt)
print (res1[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params5[0]), plot=plt)
print (res1[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params6[0]), plot=plt)
print (res1[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params7[0]), plot=plt)
print (res1[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params8[0]), plot=plt)
print (res1[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.dweibull(params9[0]), plot=plt)
print (res1[1])
res0[8]=res1[1][2]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# (1.384202850785695, 5051.111642014693, 6652.205261272384)
# (1.3275756598697968, 5034.674808253319, 6000)
# (1.3732577657394458, 5048.612923306428, 6500)
# (1.4038984146074076, 5054.814315054269, 7000)
# (1.7938758197120495, 6752.430387910332, 7500)
# (1.8107592965775652, 6769.518141533539, 7800)
# (1.8161323968176546, 6777.333140456211, 8000)
# (1.8102355664163632, 6786.910006300292, 8500)
# (1.3275756598697968, 5034.674808253319, 6000)
# (6367.66491151459, 6607.407407407407, 0.90889466926044)
# (6247.452268188794, 6607.407407407407, 0.9058661222990642)
# (6345.52207542469, 6607.407407407407, 0.9083511398246993)
# (6406.258659783765, 6607.407407407407, 0.9098254573199946)
# (6916.595859623436, 6607.407407407407, 0.9192327463599155)
# (6930.495781795254, 6607.407407407407, 0.9193673885246857)
# (6934.813110576518, 6607.407407407407, 0.9194069510763334)
# (6930.072245807034, 6607.407407407407, 0.919363448510962)
# (6247.452268188794, 6607.407407407407, 0.9058661222990642)

# %% [markdown]
# ## Exponential Weibull

# %%
#params1 = s.exponweib.fit(data_h["部件本次装机使用小时"])
params1 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, fc=0.001)
params2 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.005)
params3 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.01)
params4 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.05)
params5 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.1)
params6 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.3)
params7 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.5)
params8 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=1)
params9 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=1.5)

print (params1)
print (params2)
print (params3)
print (params4)
print (params5)
print (params6)
print (params7)
print (params8)
print (params9)

ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params1[0], params1[1]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params2[0], params2[1]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params3[0], params3[1]), plot=plt)
print (res1[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params4[0], params4[1]), plot=plt)
print (res1[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params5[0], params5[1]), plot=plt)
print (res1[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params6[0], params6[1]), plot=plt)
print (res1[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params7[0], params7[1]), plot=plt)
print (res1[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params8[0], params8[1]), plot=plt)
print (res1[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params9[0], params9[1]), plot=plt)
print (res1[1])
res0[8]=res1[1][2]
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# (2.2313300878328555, 0.001, 0, 2.381316476719296e-20)
# (0.005, 70.1554158489877, 0, 21250.120166597317)
# (0.01, 35.10912823620525, 0, 21640.55150912112)
# (0.05, 7.07043003844845, 0, 22288.955676949936)
# (0.1, 3.6083962505254394, 0, 21213.416404542226)
# (0.3, 1.3249653097462282, 0, 15169.20713467566)
# (0.5, 0.8571002435462567, 0, 10319.833988469874)
# (1, 0.5057199587303198, 0, 4022.4904269028075)
# (1.5, 0.38803423141252114, 0, 1766.572334910978)
# (nan, nan, nan)
# (26001.933697570563, -56.95655779178014, 0.9855013517739668)
# (25988.1090717151, -58.944996484839976, 0.9854619655631973)
# (25208.846579740497, 26.132239694763484, 0.9817730440410355)
# (23165.206079109514, 223.53902379959618, 0.9738311964464487)
# (13891.52276866435, 1155.7239774498084, 0.9342172856382515)
# C:\Users\tingting.yang\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:1248: RuntimeWarning: overflow encountered in power
# ...

# %%
params11 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.005)
params12 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=1, f0=0.005)
params13 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=2, f0=0.005)
params14 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=5, f0=0.005)
params15 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=10, f0=0.005)
params16 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=20, f0=0.005)
params17 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=50, f0=0.005)
params18 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=100, f0=0.005)
params19 = s.exponweib.fit(data_h["部件本次装机使用小时"], floc=200, f0=0.005)
ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params11[0], params11[1]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]

ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params12[0], params12[1]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params13[0], params13[1]), plot=plt)
print (res1[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params14[0], params14[1]), plot=plt)
print (res1[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params15[0], params15[1]), plot=plt)
print (res1[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params16[0], params16[1]), plot=plt)
print (res1[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params17[0], params17[1]), plot=plt)
print (res1[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params18[0], params18[1]), plot=plt)
print (res1[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params19[0], params19[1]), plot=plt)
print (res1[1])
res0[8]=res1[1][2]
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# C:\Users\tingting.yang\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:1240: RuntimeWarning: invalid value encountered in add
#   negxc + sc.xlogy(c - 1.0, x))
# (26001.933697570563, -56.95655779178014, 0.9855013517739668)
# (26019.931488443355, -39.255209993586504, 0.9853804919950795)
# (26039.103968139454, -20.48262922435788, 0.9852476947396344)
# (26106.263586568, 44.60955702733372, 0.9847499254227741)
# (26308.082389075746, 234.39138434009692, 0.9829573008520042)
# (25374.979200481976, -731.4577794388497, 0.9872142730073974)
# (24881.052755636178, -1380.8327243283838, 0.9843983587982525)
# (24083.539443745372, -3117.418905747364, 0.9636014428297826)
# (23945.67704283954, -4101.974731135638, 0.9478039160343146)

# %%
values,bins,hist = plt.hist(data_h["部件本次装机使用小时"],bins=51,range=(0,20000),normed=True)
center = (bins[:-1] + bins[1:]) / 2.
bins=bins[1:]
# plt.plot(bins, values,'o', markersize=4, label='data')
plt.plot(center,s.exponweib.pdf(center,*params1),lw=4,label='s1')
plt.plot(center,s.exponweib.pdf(center,*params3),lw=4,label='s3')
plt.plot(center,s.exponweib.pdf(center,*params16),lw=4,label='s16')
def weibull(u,shape,scale):
    return (shape / scale) * (u / scale)**(shape-1) * np.exp(-(u/scale)**shape)

# plt.plot(center,weibull(center,shape,scale),label='func',lw=2)
plt.legend()

# %%
ax1=plt.subplot(221)
plt.plot(s.exponweib.pdf(center,*params16))
ax1=plt.subplot(222)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponweib(params16[0], params16[1]), plot=plt)
ax1=plt.subplot(223)
plt.plot(s.exponweib.sf(center,*params16))
ppf=s.exponweib.ppf(0.1,*params16)
print (ppf)
ppf=s.exponweib.ppf(0.5,*params16)
print (ppf)
ppf=s.exponweib.ppf(0.9,*params16)
print (ppf)

ppf=s.exponweib.isf(0.1,*params16)
print (ppf)
ppf=s.exponweib.isf(0.5,*params16)
print (ppf)
ppf=s.exponweib.isf(0.9,*params16)
print (ppf)

ax1=plt.subplot(224)
hz = s.exponweib.pdf(center,*params16)/s.exponweib.sf(center,*params16)
plt.plot(hz)
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(s.exponweib.cdf(center,*params16))
# Out:
# 99.58367537250108
# 3950.3537214953453
# 16348.94520439013
# 16348.94520439013
# 3950.3537214953453
# 99.58367537250102

# %%
plt.plot(s.exponweib.cdf(center,*params16))

# %%
params1 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.05)
params2 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=1)
params3 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=5)
params4 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=10)
params5 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=50)
params6 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=100)
params7 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=500)
params8 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=1000)
params9 = s.exponnorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=5000)
print (params5)
ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params1[0], params1[1]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params2[0], params2[1]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params3[0], params3[1]), plot=plt)
print (res3[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params4[0], params4[1]), plot=plt)
print (res4[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params5[0], params5[1]), plot=plt)
print (res5[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params6[0], params6[1]), plot=plt)
print (res6[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params7[0], params7[1]), plot=plt)
print (res7[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params8[0], params8[1]), plot=plt)
print (res8[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params9[0], params9[1]), plot=plt)
print (res9[1])
res0[8]=res1[1][2]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# (50, 0, 124.39156461337092)
# (7127.284174105645, 6251.077166700806, 0.9084395136791463)
# (5292.189896179298, 1411.4321169415234, 0.9277294922214091)
# (6470.4046403115435, 3399.4287875032983, 0.9150107167587329)
# (5292.189896179298, 1411.4321169415234, 0.9277294922214091)
# (3463.4979526989596, -144.0459450828739, 0.9398476732734447)
# (1544.1173599689214, -880.8200268142109, 0.9462959703845275)
# (785.1978053556918, -995.935973053427, 0.9476402444376042)
# (394.141697566817, -1019.9897880221533, 0.9479916764092454)
# (157.79256482941585, -1023.4249159163546, 0.9480727855282065)

# %%
params1 = s.exponnorm.fit(data_h["部件本次装机使用小时"],  f0=0.05)
params2 = s.exponnorm.fit(data_h["部件本次装机使用小时"],  f0=1)
params3 = s.exponnorm.fit(data_h["部件本次装机使用小时"],  f0=5)
params4 = s.exponnorm.fit(data_h["部件本次装机使用小时"], f0=10)
params5 = s.exponnorm.fit(data_h["部件本次装机使用小时"], f0=50)
params6 = s.exponnorm.fit(data_h["部件本次装机使用小时"],  f0=100)
params7 = s.exponnorm.fit(data_h["部件本次装机使用小时"], f0=500)
params8 = s.exponnorm.fit(data_h["部件本次装机使用小时"], f0=1000)
params9 = s.exponnorm.fit(data_h["部件本次装机使用小时"], f0=5000)
print (params5)
ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params1[0], params1[1]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params2[0], params2[1]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params3[0], params3[1]), plot=plt)
print (res3[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params4[0], params4[1]), plot=plt)
print (res4[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params5[0], params5[1]), plot=plt)
print (res5[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params6[0], params6[1]), plot=plt)
print (res6[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params7[0], params7[1]), plot=plt)
print (res7[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params8[0], params8[1]), plot=plt)
print (res8[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.exponnorm(params9[0], params9[1]), plot=plt)
print (res9[1])
res0[8]=res1[1][2]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# C:\Users\tingting.yang\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\_continuous_distns.py:1191: RuntimeWarning: divide by zero encountered in log
#   return exparg + np.log(0.5 * invK * sc.erfc(-(x - invK) / np.sqrt(2)))
# (50, -213.82158567774002, 131.47957991536703)
# (7127.284174106042, -44454951.45082952, 0.9084395136791309)
# (5292.189896179217, -6587614.625576517, 0.9277294922214075)
# (6470.4046403115435, 3399.4287875032983, 0.9150107167587329)
# (5292.189896179298, 1411.4321169415234, 0.9277294922214091)
# (3463.4979526989596, -144.0459450828739, 0.9398476732734447)
# (1544.1173599689214, -880.8200268142109, 0.9462959703845275)
# (785.1978053556918, -995.935973053427, 0.9476402444376042)
# (394.141697566817, -1019.9897880221533, 0.9479916764092454)
# (157.79256482941585, -1023.4249159163546, 0.9480727855282065)

# %%
params1 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.001)
params2 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.005)
params3 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.01)
params4 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.05)
params5 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.1)
params6 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.3)
params7 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.5)
params8 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=1)
params9 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=1.5)

# params1 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.005)
# params2 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=1, f0=0.005)
# params3 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=2, f0=0.005)
# params4 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=5, f0=0.005)
# params5 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=10, f0=0.005)
# params6 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=20, f0=0.005)
# params7 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=50, f0=0.005)
# params8 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=100, f0=0.005)
# params9 = s.lognorm.fit(data_h["部件本次装机使用小时"], floc=200, f0=0.005)

ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params1[0], params1[1]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params2[0], params2[1]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params3[0], params3[1]), plot=plt)
print (res1[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params4[0], params4[1]), plot=plt)
print (res1[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params5[0], params5[1]), plot=plt)
print (res1[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params6[0], params6[1]), plot=plt)
print (res1[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params7[0], params7[1]), plot=plt)
print (res1[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params8[0], params8[1]), plot=plt)
print (res1[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.lognorm(params9[0], params9[1]), plot=plt)
print (res1[1])
res0[8]=res1[1][2]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# (7137435.927298196, -7130831.681361591, 0.908600033180831)
# (1428560.3582141045, -1421968.770113873, 0.9092946396478471)
# (714927.2238665301, -708351.4841675672, 0.9101544024806901)
# (143829.5039577891, -137381.43959036915, 0.9166884159705029)
# (72200.22100021924, -65913.20316521185, 0.9239772263632662)
# (23553.27440586166, -17900.37824631383, 0.9429803147770522)
# (13054.039089191734, -7959.794331227878, 0.9457600169093304)
# (4303.567372719524, 13.459470420510115, 0.8951812779109578)
# (1507.3680863985476, 2825.0830294730445, 0.802736503039197)

# %%
# params1 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.001)
# params2 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.005)
# params3 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.01)
# params4 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.05)
# params5 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.1)
# params6 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.3)
# params7 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=0.5)
# params8 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=1)
# params9 = s.logistic.fit(data_h["部件本次装机使用小时"], floc=0, f0=1.5)

params1 = s.logistic.fit(data_h["部件本次装机使用小时"])
params2 = s.logistic.fit(data_h["部件本次装机使用小时"])
params3 = s.logistic.fit(data_h["部件本次装机使用小时"])
params4 = s.logistic.fit(data_h["部件本次装机使用小时"])
params5 = s.logistic.fit(data_h["部件本次装机使用小时"])
params6 = s.logistic.fit(data_h["部件本次装机使用小时"])
params7 = s.logistic.fit(data_h["部件本次装机使用小时"])
params8 = s.logistic.fit(data_h["部件本次装机使用小时"])
params9 = s.logistic.fit(data_h["部件本次装机使用小时"])

ax1=plt.subplot(331)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params1[0], params1[1]), plot=plt)
print (res1[1])
res0 = np.zeros(9)
res0[0]=res1[1][2]
ax1=plt.subplot(332)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params2[0], params2[1]), plot=plt)
print (res1[1])
res0[1]=res1[1][2]

ax1=plt.subplot(333)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params3[0], params3[1]), plot=plt)
print (res1[1])
res0[2]=res1[1][2]

ax1=plt.subplot(334)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params4[0], params4[1]), plot=plt)
print (res1[1])
res0[3]=res1[1][2]

ax1=plt.subplot(335)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params5[0], params5[1]), plot=plt)
print (res1[1])
res0[4]=res1[1][2]

ax1=plt.subplot(336)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params6[0], params6[1]), plot=plt)
print (res1[1])
res0[5]=res1[1][2]

ax1=plt.subplot(337)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params7[0], params7[1]), plot=plt)
print (res1[1])
res0[6]=res1[1][2]

ax1=plt.subplot(338)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params8[0], params8[1]), plot=plt)
print (res1[1])
res0[7]=res1[1][2]

ax1=plt.subplot(339)
res1 = s.probplot(data_h["部件本次装机使用小时"],dist=s.logistic(params9[0], params9[1]), plot=plt)
print (res1[1])
res0[8]=res1[1][2]

fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(res0)
plt.show()
# Out:
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
# (0.9376043284794354, 1337.2307109612166, 0.8975852612252356)
