# %%
# 故障零件数据
887477（新版）.xlsx  / 57186-10与-11合版.xlsx (即57186-10新版 和 57186-11新版)
# 无故障零件数据
887477 EMDP现装机.xlsx /  57186-10 EMDP现装机.xlsx【57186-11 EMDP现装机.xlsx】

# %% [markdown]
# #### 887477（新版）.xlsx

# %%
import pandas as pd
data1 = pd.read_excel('887477（新版）.xlsx',encoding='gb18030')
pd.read_excel('887477（新版）.xlsx',encoding='gb18030').columns
# Out:
# Index(['件号', '序号', '收料日期', '备注', '修理厂家', '拆件原因', '修理报告概况', '飞机', '拆下时TSI FH',
#        '拆下时TSI CY', '拆下时TSN FH', '拆下时TSN CY', 'Unnamed: 12',
#        '上次安装TSN FH（仅用于计算）', '上次安装TSN CY（仅用于计算）', '更换次数'],
#       dtype='object')

# %%
data1
# Out:
#         件号         序号       收料日期          备注   修理厂家          拆件原因  \
# 0   887477  MX-537132 2018-09-29         NaN   武汉航达        EMDP漏油
# 1   887477  MX-537132 2017-01-16         NaN   武汉航达        EMDP漏油
# 2   887477  MX-543638 2016-07-26         NaN   武汉航达        EMDP漏油
# 3   887477  MX-555477 2018-09-21         NaN   武汉航达        EMDP漏油
# 4   887477  MX-555477 2009-12-25         NaN   武汉航达        EMDP漏油
# 5   887477   MX603630 2019-05-09         NaN   武汉航达        EMDP漏油
# 6   887477   MX603630 2018-12-13         NaN   武汉航达        EMDP漏油
# 7   887477   MX603630 2012-09-18         NaN    无记录           无记录
# 8   887477   MX603630 2009-05-28         NaN   武汉航达        EMDP漏油
# 9   887477   MX603630 2007-10-27         NaN   武汉航达        EMDP漏油
# 10  887477   MX603630 2006-11-10         NaN   武汉航达        EMDP漏油
# 11  887477  MX620435A 2016-06-02         NaN   武汉航达        EMDP漏油
# 12  887477  MX620435A 2015-04-22         NaN   武汉航达        EMDP漏油
# ...

# %%
data1['上次安装TSN FH（仅用于计算）'].fillna(0,inplace=True)
data1['上次安装TSN FH（仅用于计算）']
# Out:
# 0     53629.0
# 1         0.0
# 2         0.0
# 3     44027.0
# 4         0.0
# 5     34380.0
# 6     27062.0
# 7     20381.0
# 8     16109.0
# 9     15679.0
# 10        0.0
# 11    28180.0
# 12    13456.0
# 13        0.0
# 14        0.0
# 15    17725.0
# 16        0.0
# 17        0.0
# 18        0.0
# 19     8352.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        0.0
# 24        0.0
# Name: 上次安装TSN FH（仅用于计算）, dtype: float64

# %%
data1['上次安装TSN CY（仅用于计算）'].fillna(0,inplace=True)
data1['上次安装TSN CY（仅用于计算）']
# Out:
# 0     34176.0
# 1         0.0
# 2         0.0
# 3     29041.0
# 4         0.0
# 5     25569.0
# 6     21641.0
# 7     16891.0
# 8     13935.0
# 9     13716.0
# 10        0.0
# 11    15860.0
# 12     8747.0
# 13        0.0
# 14        0.0
# 15    14936.0
# 16        0.0
# 17        0.0
# 18        0.0
# 19     3927.0
# 20        0.0
# 21        0.0
# 22        0.0
# 23        0.0
# 24        0.0
# Name: 上次安装TSN CY（仅用于计算）, dtype: float64

# %%
data1['TNS FH'] = data1['拆下时TSN FH'] - data1['上次安装TSN FH（仅用于计算）']
data1['TNS FH']
# Out:
# 0      4016.0
# 1     53629.0
# 2     53365.0
# 3     17032.0
# 4     44027.0
# 5       538.0
# 6      7318.0
# 7      6681.0
# 8      4272.0
# 9       430.0
# 10    15679.0
# 11     3089.0
# 12    14724.0
# 13    13456.0
# 14    51198.0
# 15     1519.0
# 16    17725.0
# 17    49857.0
# 18    55014.0
# 19        8.0
# 20     8352.0
# 21    15798.0
# 22     9907.0
# 23    16232.0
# 24     6875.0
# Name: TNS FH, dtype: float64

# %%
data1['TNS CY'] = data1['拆下时TSN CY'] - data1['上次安装TSN CY（仅用于计算）']
data1['TNS CY']
# Out:
# 0      1814.0
# 1     34176.0
# 2     34283.0
# 3      7708.0
# 4     29041.0
# 5       265.0
# 6      3928.0
# 7      4750.0
# 8      2956.0
# 9       219.0
# 10    13716.0
# 11     1298.0
# 12     7113.0
# 13     8747.0
# 14    30157.0
# 15      682.0
# 16    14936.0
# 17    30976.0
# 18    33271.0
# 19        4.0
# 20     3927.0
# 21     8069.0
# 22     4664.0
# 23     8726.0
# 24     4679.0
# Name: TNS CY, dtype: float64

# %%
data1["status"] = True
data1 = data1[['件号', '修理厂家', '修理报告概况', '更换次数', 'TNS FH', 'TNS CY', 'status']]
data1
# Out:
#         件号   修理厂家        修理报告概况  更换次数   TNS FH   TNS CY  status
# 0   887477   武汉航达       轴承与轴封磨损   2.0   4016.0   1814.0    True
# 1   887477   武汉航达       轴承与轴封磨损   1.0  53629.0  34176.0    True
# 2   887477   武汉航达      轴承与轴封磨损，   1.0  53365.0  34283.0    True
# 3   887477   武汉航达       轴承与轴封磨损   2.0  17032.0   7708.0    True
# 4   887477   武汉航达      轴承与轴封磨损，   1.0  44027.0  29041.0    True
# 5   887477   武汉航达          壳体漏油   6.0    538.0    265.0    True
# 6   887477   武汉航达       轴承与轴封磨损   5.0   7318.0   3928.0    True
# 7   887477    无记录           无记录   4.0   6681.0   4750.0    True
# 8   887477   武汉航达       轴承与轴封磨损   3.0   4272.0   2956.0    True
# 9   887477   武汉航达       轴承与轴封磨损   2.0    430.0    219.0    True
# 10  887477   武汉航达      轴承与轴封磨损，   1.0  15679.0  13716.0    True
# 11  887477   武汉航达       轴承与轴封磨损   3.0   3089.0   1298.0    True
# 12  887477   武汉航达       轴承与轴封磨损   2.0  14724.0   7113.0    True
# 13  887477   武汉航达           无记录   1.0  13456.0   8747.0    True
# ...

# %%
data1[data1['更换次数'] == 1.0]
# Out:
#         件号   修理厂家        修理报告概况  更换次数   TNS FH   TNS CY  status
# 1   887477   武汉航达       轴承与轴封磨损   1.0  53629.0  34176.0    True
# 2   887477   武汉航达      轴承与轴封磨损，   1.0  53365.0  34283.0    True
# 4   887477   武汉航达      轴承与轴封磨损，   1.0  44027.0  29041.0    True
# 10  887477   武汉航达      轴承与轴封磨损，   1.0  15679.0  13716.0    True
# 13  887477   武汉航达           无记录   1.0  13456.0   8747.0    True
# 14  887477   武汉航达      轴承与轴封磨损，   1.0  51198.0  30157.0    True
# 16  887477   武汉航达          轴承失效   1.0  17725.0  14936.0    True
# 20  887477  EATON      轴承与轴封磨损，   1.0   8352.0   3927.0    True
# 21  887477  EATON          轴封磨损   1.0  15798.0   8069.0    True
# 22  887477  EATON        叶轮外壳裂纹   1.0   9907.0   4664.0    True
# 23  887477   武汉航达  插座损坏，轴承与轴封磨损   1.0  16232.0   8726.0    True
# 24  887477  EATON          轴封磨损   1.0   6875.0   4679.0    True

# %% [markdown]
# #### 887477 EMDP现装机.xlsx

# %%
pd.read_excel('887477 EMDP现装机.xlsx',encoding='gb18030').columns
# Out:
# Index(['R', 'Av', 'Cond', 'P/n', 'S/n', 'Alt.Tp', 'TP', 'Serialized', 'Vendor',
#        'Owner', 'Unit', 'Msn', 'A/c-Reg', 'Ata', 'Zone', 'Fin',
#        'Fin Description', 'Stock', 'Location', 'Inventory', 'L', 'B/n', 'Qty',
#        'Reserved', 'Type', 'Order#', 'State', 'Organisation', 'Assy P/n',
#        'Assy S/n', 'Expir', 'stock date ', 'installation', 'removal date',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %% [markdown]
# Index(['机型', '制造序列号', '机号', '参考类型', '指令类型', '件号', '序号', '章节号', '非计划', '故障确认',
#        '拆换原因', '安装日期', '部件装上飞行小时数', '部件装上飞行循环数', '部件装上使用小时数', '部件装上使用循环数',
#        '拆换日期', '部件拆下飞行小时数', '部件拆下飞行循环数', '部件拆下使用小时数', '部件拆下使用循环数', '故障描述',
#        '部件本次装机使用小时', '故障处理', '部件本次装机使用循环', '装上件号', '装上序号', '最近送修公司', 'CY TSN',
#        'FH TSN', '送修至拆下时间/FH', '送修至拆下时间/CY', '件号描述', 'DEF#', 'TLB号'],
#       dtype='object')

# %%
data2 = pd.read_excel('887477 EMDP现装机.xlsx',encoding='gb18030')
data2
# Out:
#       R  Av             Cond     P/n        S/n        Alt.Tp  \
# 0     I   =  Interchangeable       S          =  Superceeding
# 1   NaN  IN               IN  887477  MX-537132           NaN
# 2   NaN  IN               IN  887477  MX-503088           NaN
# 3   NaN  IN               IN  887477   MX652408           NaN
# 4   NaN  IN               IN  887477   MX654112           NaN
# 5   NaN  IN               IN  887477  MX-543638           NaN
# 6   NaN  IN               IN  887477  MX-555477           NaN
# 7   NaN  IN               IN  887477  MX-543639           NaN
# 8   NaN  IN               IN  887477  MX-492433           NaN
# 9   NaN  IN               IN  887477  MX-492434           NaN
# 10  NaN  IN               IN  887477   MX621721           NaN
# 11  NaN  IN               IN  887477   MX621720           NaN
# 12  NaN  IN               IN  887477  MX615683A           NaN
# 13  NaN  IN               IN  887477   MX651675           NaN
# ...

# %%
data2 = data2[1:]
installed_data = pd.to_datetime(data2["installation"])
installed_data
# Out:
# 1    2018-12-29
# 2    2016-01-09
# 3    2012-09-13
# 4    2002-06-07
# 5    2016-12-16
# 6    2018-10-31
# 7    2016-07-01
# 8    2009-05-27
# 9    2010-09-27
# 10   2015-05-21
# 11   2018-11-24
# 12   2012-07-10
# 13   2017-08-20
# 14   2017-08-14
# 15   2018-08-26
# 16   1999-03-23
# 17   2016-05-04
# 18   2004-12-01
# 19   2006-12-14
# 20   2013-08-28
# 21   2013-08-28
# 22   2012-09-27
# 23   2017-08-11
# 24   2017-10-26
# 25   2018-03-29
# 26   2012-07-17
# 27   2012-07-17
# 28   2013-03-15
# 29   2013-03-15
# 30   2016-01-21
# 31   2016-01-21
# 32   2019-04-12
# 33   2012-11-28
# 34   2016-07-27
# 35   2016-07-27
# 36   2016-05-20
# 37   2016-05-20
# 38   2013-05-29
# 39   2016-12-06
# 40   2015-04-21
# 41   2015-06-22
# 42   2015-06-22
# 43   2015-10-19
# 44   2015-10-19
# 45   2015-12-02
# 46   2015-12-02
# 47   2017-09-01
# 48   2015-04-18
# 49   2013-03-12
# 50   2019-01-26
# 51   2000-06-08
# 52   2018-07-25
# 53   2015-04-21
# 54   2004-11-22
# ...

# %%
import datetime
now_time = datetime.datetime.now()#.strftime('%Y-%m-%d')
now_time
# Out:
# datetime.datetime(2020, 1, 2, 10, 3, 9, 147658)

# %%
L = []
for i in installed_data:
    i = str(i).split(" ")[0]
    i = time.strptime(i, "%Y-%m-%d")
    date1 = datetime.datetime(i[0], i[1], i[2])
    diff_days = (now_time - date1).days
    L.append(diff_days)
print(L)
# Out:
# [369, 1454, 2667, 6418, 1112, 428, 1280, 3872, 3384, 1687, 404, 2732, 865, 871, 494, 7590, 1338, 5510, 4767, 2318, 2318, 2653, 874, 798, 644, 2725, 2725, 2484, 2484, 1442, 1442, 265, 2591, 1254, 1254, 1322, 1322, 2409, 1122, 1717, 1655, 1655, 1536, 1536, 1492, 1492, 853, 1720, 2487, 341, 7147, 526, 1717, 5519]

# %%
data2["部件本次装机使用小时"] = L

data2["status"] = False

data2["安装日期"] = pd.to_datetime(data2["installation"])
data2["安装年度"] = data2["安装日期"].dt.year

data2["PartType"] = data2["removal date"]
data2.loc[data2["PartType"] == data2["PartType"], "PartType"] = "PartOld"
data2["PartType"].fillna("PartNew", inplace=True)
# Out:
# C:\Users\shuangyang.luo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\shuangyang.luo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
data2 = data2[["P/n", "安装年度", "PartType", "部件本次装机使用小时", "status"]]
data2
# Out:
#        P/n  安装年度 PartType  部件本次装机使用小时  status
# 1   887477  2018  PartOld         369   False
# 2   887477  2016  PartOld        1454   False
# 3   887477  2012  PartOld        2667   False
# 4   887477  2002  PartNew        6418   False
# 5   887477  2016  PartOld        1112   False
# 6   887477  2018  PartOld         428   False
# 7   887477  2016  PartOld        1280   False
# 8   887477  2009  PartOld        3872   False
# 9   887477  2010  PartOld        3384   False
# 10  887477  2015  PartOld        1687   False
# 11  887477  2018  PartOld         404   False
# 12  887477  2012  PartOld        2732   False
# 13  887477  2017  PartOld         865   False
# 14  887477  2017  PartOld         871   False
# 15  887477  2018  PartOld         494   False
# 16  887477  1999  PartNew        7590   False
# 17  887477  2016  PartOld        1338   False
# 18  887477  2004  PartNew        5510   False
# 19  887477  2006  PartOld        4767   False
# ...

# %% [markdown]
# #### 57186-10与-11合版.xlsx

# %%
pd.read_excel('57186-10与-11合版.xlsx', encoding="gb18030").columns
# Out:
# Index(['件号', '序号', '收料日期', '备注', '修理厂家', '拆件原因', '修理报告概况', '飞机', '拆下时TSI FH',
#        '拆下时TSI CY', '拆下时TSN FH', '拆下时TSN CY', 'Unnamed: 12',
#        '上次安装TSN FH（仅用于计算）', '上次安装TSN CY（仅用于计算）', '次数', '备注.1'],
#       dtype='object')

# %%
data1 = pd.read_excel('57186-10与-11合版.xlsx', encoding="gb18030")
data1
# Out:
#            件号         序号       收料日期          备注   修理厂家        拆件原因  \
# 0    57186-10     161056 2017-02-13         NaN   武汉航达  壳体回油滤大量金属屑
# 1    57186-10     161056 2008-12-04         NaN     不明          不明
# 2    57186-10     161056 2006-09-05         NaN   武汉航达  壳体回油滤大量金属屑
# 3    57186-10     200464 2019-07-10         NaN   武汉航达        过热灯亮
# 4    57186-10     200464 2007-02-16         NaN   武汉航达        过热灯亮
# 5    57186-10     248394 2019-09-20         NaN   武汉航达          不明
# 6    57186-10     248394 2019-04-16  2019-05-17  PAKER       系统压力低
# 7    57186-10     248394 2010-05-30         NaN   武汉航达        低压灯亮
# 8    57186-10     248394 2008-05-09         NaN   武汉航达  壳体回油滤大量金属屑
# 9    57186-10     270332 2019-09-04         NaN   武汉航达  壳体回油滤大量金属屑
# 10   57186-10     270332 2007-10-07         NaN   武汉航达  壳体回油滤大量金属屑
# 11   57186-10     270392 2017-08-29         NaN   武汉航达   壳体回油滤有金属屑
# 12   57186-10     279458 2018-01-10         NaN   武汉航达        过热灯亮
# ...

# %%
data = data1[data1['件号'] == '57186-11']
data.to_excel("data/57186-11（新版）.xlsx", encoding="UTF-8", index=False)

# %%
pd.read_excel("data/57186-11（新版）.xlsx", encoding="UTF-8")
# Out:
#           件号    修理厂家                                         修理报告概况  次数  \
# 0   57186-11    航新科技                                        壳体密封件失效   5
# 1   57186-11    武汉航达                                          密封件失效   3
# 2   57186-11    武汉航达                          油液中有金属屑，不宜预测试。耳轴，轴承损坏   2
# 3   57186-11    武汉航达                           耳轴、轴承、耳轴轴承、摆架磨损，插座损坏   1
# 4   57186-11  PARKER                                           马达故障   3
# 5   57186-11  PARKER                                            NFF   1
# 6   57186-11  PARKER                                        电流测试未通过   4
# 7   57186-11  PARKER                        更换马达，插头损坏，更换CAP,HOUSING   3
# 8   57186-11  PARKER                                  更换BRACKET,与线束   2
# 9   57186-11  PARKER  因为MISSING更换JUMPER ASSY,CLAMP,SCREW,WASHER,NUT   1
# 10  57186-11  PARKER                                            NFF   2
# 11  57186-11   PAKER                                      调节弹簧和螺钉故障   1
# ...

# %%
data = data1[data1['件号'] == '57186-10']
data.to_excel("data/57186-10（新版）.xlsx", encoding="UTF-8", index=False)

# %%
len(data1[data1['件号'] == '57186-11'])
# Out:
# 16

# %%
len(data1[data1['件号'] == '57186-10'])
# Out:
# 188

# %%
data1['上次安装TSN FH（仅用于计算）'].fillna(0,inplace=True)
data1['上次安装TSN CY（仅用于计算）'].fillna(0,inplace=True)
data1['TNS FH'] = data1['拆下时TSN FH'] - data1['上次安装TSN FH（仅用于计算）']
data1['TNS CY'] = data1['拆下时TSN CY'] - data1['上次安装TSN CY（仅用于计算）']
data1["status"] = False
data1 = data1[['件号', '修理厂家', '修理报告概况', '次数', 'TNS FH', 'TNS CY', 'status']]
data1[data1['次数'] == 1.0]
data1
# Out:
#            件号   修理厂家                               修理报告概况   次数   TNS FH  \
# 0    57186-10   武汉航达                           轴承、摆架、油缸磨损  3.0  11644.0
# 1    57186-10     不明                                   不明  2.0   6248.0
# 2    57186-10   武汉航达                   耳轴、插座损坏；轴承、摆架、油缸磨损  1.0  27146.0
# 3    57186-10   武汉航达                油液中有金属屑，不宜预测试。摆架，轴承磨损  2.0  38520.0
# 4    57186-10   武汉航达      摆架，耳轴损伤；阀芯、阀套卡死；油缸、轴承磨损；橡胶密封件失效  1.0  38954.0
# 5    57186-10   武汉航达                               安装脚断裂，  4.0  72259.0
# 6    57186-10  PAKER                                 马达损坏  3.0  25479.0
# 7    57186-10   武汉航达                                 轴承磨损  2.0   6479.0
# 8    57186-10   武汉航达                  壳体，摆架，耳轴损伤；轴承与油缸磨损；  1.0  40301.0
# 9    57186-10   武汉航达                油液中有金属屑，不宜预测试。轴承，油缸磨损  2.0  33692.0
# 10   57186-10   武汉航达                  螺钉、摆架和耳轴损伤；油缸和轴承磨损；  1.0  24539.0
# 11   57186-10   武汉航达                     轴承、摆架、螺钉、垫片、油缸磨损  1.0  25831.0
# ...

# %%
data1[data1['件号'] == '57186-11']
# Out:
#            件号    修理厂家                                         修理报告概况   次数  \
# 23   57186-11    航新科技                                        壳体密封件失效  5.0
# 51   57186-11    武汉航达                                          密封件失效  3.0
# 67   57186-11    武汉航达                          油液中有金属屑，不宜预测试。耳轴，轴承损坏  2.0
# 68   57186-11    武汉航达                           耳轴、轴承、耳轴轴承、摆架磨损，插座损坏  1.0
# 116  57186-11  PARKER                                           马达故障  3.0
# 151  57186-11  PARKER                                            NFF  1.0
# 152  57186-11  PARKER                                        电流测试未通过  4.0
# 153  57186-11  PARKER                        更换马达，插头损坏，更换CAP,HOUSING  3.0
# 154  57186-11  PARKER                                  更换BRACKET,与线束  2.0
# 155  57186-11  PARKER  因为MISSING更换JUMPER ASSY,CLAMP,SCREW,WASHER,NUT  1.0
# 156  57186-11  PARKER                                            NFF  2.0
# 157  57186-11   PAKER                                      调节弹簧和螺钉故障  1.0
# ...

# %%
data1[data1['件号'] == '57186-10']
# Out:
#            件号   修理厂家                               修理报告概况   次数   TNS FH  \
# 0    57186-10   武汉航达                           轴承、摆架、油缸磨损  3.0  11644.0
# 1    57186-10     不明                                   不明  2.0   6248.0
# 2    57186-10   武汉航达                   耳轴、插座损坏；轴承、摆架、油缸磨损  1.0  27146.0
# 3    57186-10   武汉航达                油液中有金属屑，不宜预测试。摆架，轴承磨损  2.0  38520.0
# 4    57186-10   武汉航达      摆架，耳轴损伤；阀芯、阀套卡死；油缸、轴承磨损；橡胶密封件失效  1.0  38954.0
# 5    57186-10   武汉航达                               安装脚断裂，  4.0  72259.0
# 6    57186-10  PAKER                                 马达损坏  3.0  25479.0
# 7    57186-10   武汉航达                                 轴承磨损  2.0   6479.0
# 8    57186-10   武汉航达                  壳体，摆架，耳轴损伤；轴承与油缸磨损；  1.0  40301.0
# 9    57186-10   武汉航达                油液中有金属屑，不宜预测试。轴承，油缸磨损  2.0  33692.0
# 10   57186-10   武汉航达                  螺钉、摆架和耳轴损伤；油缸和轴承磨损；  1.0  24539.0
# 11   57186-10   武汉航达                     轴承、摆架、螺钉、垫片、油缸磨损  1.0  25831.0
# ...

# %% [markdown]
# #### "57186-10 EMDP现装机.xlsx"    <==>     "57186-11 EMDP现装机.xlsx"

# %%
pd.read_excel('57186-10 EMDP现装机.xlsx',encoding='gb18030').columns
# Out:
# Index(['R', 'Av', 'Cond', 'P/n', 'S/n', 'Alt.Tp', 'TP', 'Serialized', 'Vendor',
#        'Owner', 'Unit', 'Msn', 'A/c-Reg', 'Ata', 'Zone', 'Fin',
#        'Fin Description', 'Stock', 'Location', 'Inventory', 'L', 'B/n', 'Qty',
#        'Reserved', 'Type', 'Order#', 'State', 'Organisation', 'Assy P/n',
#        'Assy S/n', 'Expir', 'stock date ', 'installation', 'removal date',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38'],
#       dtype='object')

# %%
data1 = pd.read_excel('57186-10 EMDP现装机.xlsx',encoding='gb18030')
data = data1[data1['P/n'] == '57186-10']
data.to_excel("data/57186-10 EMDP现装机.xlsx", encoding="UTF-8", index=False)
data2 = data1[data1['P/n'] == '57186-11']
data2.to_excel("data/57186-11 EMDP现装机.xlsx", encoding="UTF-8", index=False)

# %%
pd.read_excel('data/57186-11 EMDP现装机.xlsx',encoding='gb18030')
# Out:
#      R  Av Cond       P/n         S/n  Alt.Tp  TP Serialized  Vendor Owner  \
# 0    I  IN   IN  57186-11       K0804     NaN  RO          X   93835   HNA
# 1    I  IN   IN  57186-11       K0296     NaN  RO          X   93835   YZJ
# 2    I  IN   IN  57186-11       K0765     NaN  RO          X   93835   HNA
# 3    I  IN   IN  57186-11       K1439     NaN  RO          X   93835   HNA
# 4    I  IN   IN  57186-11       K1501     NaN  RO          X   93835   HNA
# 5    I  IN   IN  57186-11       K1594     NaN  RO          X   93835   HNA
# 6    I  IN   IN  57186-11       K2470     NaN  RO          X   93835   HNA
# 7    I  IN   IN  57186-11   571863700     NaN  RO          X   93835   HNA
# 8    I  IN   IN  57186-11   571863747     NaN  RO          X   93835   HNA
# 9    I  IN   IN  57186-11   571863965     NaN  RO          X   93835   HNA
# 10   I  IN   IN  57186-11   571864117     NaN  RO          X   93835   HNA
# ...

# %%
import datetime
now_time = datetime.datetime.now()#.strftime('%Y-%m-%d')
now_time

data2 = pd.read_excel('57186-10 EMDP现装机.xlsx',encoding='gb18030')
data2 = data2[1:]
installed_data = pd.to_datetime(data2["installation"])

L = []
for i in installed_data:
    i = str(i).split(" ")[0]
    i = time.strptime(i, "%Y-%m-%d")
    date1 = datetime.datetime(i[0], i[1], i[2])
    diff_days = (now_time - date1).days
    L.append(diff_days)
    
data2["部件本次装机使用小时"] = L

data2["status"] = False

data2["安装日期"] = pd.to_datetime(data2["installation"])
data2["安装年度"] = data2["安装日期"].dt.year

data2["PartType"] = data2["removal date"]
data2.loc[data2["PartType"] == data2["PartType"], "PartType"] = "PartOld"
data2["PartType"].fillna("PartNew", inplace=True) 

data2 = data2[["P/n", "安装年度", "PartType", "部件本次装机使用小时", "status"]]
data2
# Out:
#           P/n  安装年度 PartType  部件本次装机使用小时  status
# 1    57186-10  2010  PartOld        3298   False
# 2    57186-10  2014  PartOld        1985   False
# 3    57186-10  2013  PartOld        2469   False
# 4    57186-11  2018  PartOld         517   False
# 5    57186-10  2005  PartOld        5355   False
# 6    57186-10  2004  PartOld        5719   False
# 7    57186-10  2009  PartOld        3699   False
# 8    57186-10  2009  PartOld        3855   False
# 9    57186-10  2007  PartOld        4672   False
# 10   57186-10  2007  PartOld        4409   False
# 11   57186-10  2005  PartOld        5197   False
# 12   57186-10  2014  PartOld        2105   False
# 13   57186-10  2011  PartOld        3202   False
# 14   57186-10  2009  PartOld        3829   False
# 15   57186-10  2018  PartOld         717   False
# 16   57186-10  2009  PartOld        3814   False
# 17   57186-10  2008  PartOld        4023   False
# 18   57186-10  2014  PartOld        1953   False
# ...

# %%
data2[data2['P/n'] == '57186-10']
# Out:
#           P/n  安装年度 PartType  部件本次装机使用小时  status
# 1    57186-10  2010  PartOld        3298   False
# 2    57186-10  2014  PartOld        1985   False
# 3    57186-10  2013  PartOld        2469   False
# 5    57186-10  2005  PartOld        5355   False
# 6    57186-10  2004  PartOld        5719   False
# 7    57186-10  2009  PartOld        3699   False
# 8    57186-10  2009  PartOld        3855   False
# 9    57186-10  2007  PartOld        4672   False
# 10   57186-10  2007  PartOld        4409   False
# 11   57186-10  2005  PartOld        5197   False
# 12   57186-10  2014  PartOld        2105   False
# 13   57186-10  2011  PartOld        3202   False
# 14   57186-10  2009  PartOld        3829   False
# 15   57186-10  2018  PartOld         717   False
# 16   57186-10  2009  PartOld        3814   False
# 17   57186-10  2008  PartOld        4023   False
# 18   57186-10  2014  PartOld        1953   False
# 19   57186-10  2008  PartOld        4256   False
# ...

# %%
data2[data2['P/n'] == '57186-11']
# Out:
#           P/n  安装年度 PartType  部件本次装机使用小时  status
# 4    57186-11  2018  PartOld         517   False
# 22   57186-11  2019  PartOld         285   False
# 31   57186-11  2018  PartOld         487   False
# 36   57186-11  2019  PartOld         292   False
# 46   57186-11  2018  PartOld         502   False
# 47   57186-11  2018  PartOld         611   False
# 52   57186-11  2018  PartOld         600   False
# 82   57186-11  2019  PartOld         291   False
# 84   57186-11  2018  PartOld         472   False
# 92   57186-11  2019  PartOld         310   False
# 94   57186-11  2018  PartOld         409   False
# 99   57186-11  2018  PartOld         621   False
# 105  57186-11  2019  PartOld         125   False
# 111  57186-11  2018  PartOld         683   False
# 114  57186-11  2018  PartOld         669   False
# 115  57186-11  2018  PartOld         696   False
# 116  57186-11  2019  PartOld         151   False
# 125  57186-11  2018  PartOld         371   False
# ...

# %% [markdown]
# #### 57186-11 EMDP现装机.xlsx

# %%
import datetime
now_time = datetime.datetime.now()#.strftime('%Y-%m-%d')
now_time

data2 = pd.read_excel('57186-11 EMDP现装机.xlsx',encoding='gb18030')
data2 = data2[1:]
installed_data = pd.to_datetime(data2["installation"])

L = []
for i in installed_data:
    i = str(i).split(" ")[0]
    i = time.strptime(i, "%Y-%m-%d")
    date1 = datetime.datetime(i[0], i[1], i[2])
    diff_days = (now_time - date1).days
    L.append(diff_days)
    
data2["部件本次装机使用小时"] = L

data2["status"] = False

data2["安装日期"] = pd.to_datetime(data2["installation"])
data2["安装年度"] = data2["安装日期"].dt.year

data2["PartType"] = data2["removal date"]
data2.loc[data2["PartType"] == data2["PartType"], "PartType"] = "PartOld"
data2["PartType"].fillna("PartNew", inplace=True) 

data2 = data2[["P/n", "安装年度", "PartType", "部件本次装机使用小时", "status"]]
data2
# Out:
#           P/n  安装年度 PartType  部件本次装机使用小时  status
# 1    57186-10  2010  PartOld        3298   False
# 2    57186-10  2014  PartOld        1985   False
# 3    57186-10  2013  PartOld        2469   False
# 4    57186-11  2018  PartOld         517   False
# 5    57186-10  2005  PartOld        5355   False
# 6    57186-10  2004  PartOld        5719   False
# 7    57186-10  2009  PartOld        3699   False
# 8    57186-10  2009  PartOld        3855   False
# 9    57186-10  2007  PartOld        4672   False
# 10   57186-10  2007  PartOld        4409   False
# 11   57186-10  2005  PartOld        5197   False
# 12   57186-10  2014  PartOld        2105   False
# 13   57186-10  2011  PartOld        3202   False
# 14   57186-10  2009  PartOld        3829   False
# 15   57186-10  2018  PartOld         717   False
# 16   57186-10  2009  PartOld        3814   False
# 17   57186-10  2008  PartOld        4023   False
# 18   57186-10  2014  PartOld        1953   False
# ...

# %% [markdown]
# #### 3种EMDP泵（57186-10，57186-11，887477）

# %%
emdp = pd.read_csv("EMDP.csv", encoding = "GB2312")
emdp.columns
# Out:
# Index(['机型', '制造序列号', '机号', '参考类型', '指令类型', '件号', '序号', '章节号', '非计划', '故障确认',
#        '拆换原因', '安装日期', '部件装上飞行小时数', '部件装上飞行循环数', '部件装上使用小时数', '部件装上使用循环数',
#        '拆换日期', '部件拆下飞行小时数', '部件拆下飞行循环数', '部件拆下使用小时数', '部件拆下使用循环数', '故障描述',
#        '部件本次装机使用小时', '故障处理', '部件本次装机使用循环', '装上件号', '装上序号', '最近送修公司', 'CY TSN',
#        'FH TSN', '送修至拆下时间/FH', '送修至拆下时间/CY', '件号描述', 'DEF#', 'TLB号'],
#       dtype='object')

# %%
pd.read_csv("EMDP.csv", encoding = "GB2312")
# Out:
#       机型     制造序列号        机号    参考类型    指令类型                        件号  \
# 0    73C  73C02557  2937      DE      CC      57186-10
# 1    73C  73C02543  2990      DE      CC      57186-10
# 2    73C  73C02859  2982      DE      CC      57186-10
# 3    73C  73C02557  2937      DE      CC      57186-10
# 4    73C  73C02342  2579      DE      CC      57186-10
# 5    73C  73C02811  2970      DE      CC      57186-10
# 6    73C  73C02859  2982      DE      CC      57186-10
# 7    73C  73C02939  2989      DE      CC      57186-10
# 8    73C  73C02859  2982      DE      CC      57186-10
# 9    73C  73C02922  2987      DE      CC      57186-10
# 10   73C  73C02811  2970      DE      CC      57186-10
# 11   73C  73C02811  2970      DE      CC      57186-10
# 12   73C  73C02811  2970      DE      CC      57186-10
# 13   73C  73C02811  2970      DE      CC      57186-10
# 14   73C  73C02342  2579      DE      CC      57186-10
# 15   73C  73C01866  2960      DE      CC      57186-10
# ...

# %%
data_1 = emdp.loc[emdp['件号']=='57186-10                ']
data_1.to_csv("data/57186-10-EMDP.csv", encoding="UTF-8", index=False)

# %%
data_2 = emdp.loc[emdp['件号']=='57186-11                ']
data_2.to_csv("data/57186-11-EMDP.csv", encoding="UTF-8", index=False)

# %%
data_3 = emdp.loc[emdp['件号']=='887477                  ']
data_3.to_csv("data/887477-EMDP.csv", encoding="UTF-8", index=False)

# %%
import pandas as pd
pd.read_csv("data/57186-10-EMDP.csv", encoding="UTF-8")
# Out:
#       机型     制造序列号        机号    参考类型    指令类型                        件号  \
# 0    73C  73C02557  2937      DE      CC      57186-10
# 1    73C  73C02543  2990      DE      CC      57186-10
# 2    73C  73C02859  2982      DE      CC      57186-10
# 3    73C  73C02557  2937      DE      CC      57186-10
# 4    73C  73C02342  2579      DE      CC      57186-10
# 5    73C  73C02811  2970      DE      CC      57186-10
# 6    73C  73C02859  2982      DE      CC      57186-10
# 7    73C  73C02939  2989      DE      CC      57186-10
# 8    73C  73C02859  2982      DE      CC      57186-10
# 9    73C  73C02922  2987      DE      CC      57186-10
# 10   73C  73C02811  2970      DE      CC      57186-10
# 11   73C  73C02811  2970      DE      CC      57186-10
# 12   73C  73C02811  2970      DE      CC      57186-10
# 13   73C  73C02811  2970      DE      CC      57186-10
# 14   73C  73C02342  2579      DE      CC      57186-10
# 15   73C  73C01866  2960      DE      CC      57186-10
# ...

# %%
pd.read_csv("data/57186-11-EMDP.csv", encoding="UTF-8")
# Out:
#      机型     制造序列号        机号    参考类型    指令类型                        件号  \
# 0   73N  73N06724  1323      DE      CC      57186-11
# 1   73N  73N05655  6995      DE      CC      57186-11
# 2   73N  73N06210  1549      DE      CC      57186-11
# 3   73N  73N06476  1487      DE      CC      57186-11
# 4   73N  73N07136  206H      DE      CC      57186-11
# 5   73N  73N06667  1346      DE      CC      57186-11
# 6   73N  73N02668  5405      DE      CC      57186-11
# 7   73N  73N06210  1549      DE      CC      57186-11
# 8   73N  73N06218  7993      DE      CC      57186-11
# 9   73N  73N05693  6809      DE      CC      57186-11
# 10  73N  73N01382  5268      DE      CC      57186-11
#
#             序号  章节号 非计划 故障确认  ...                      装上件号              装上序号  \
# 0   5718610907   29   X    X  ...  57186-10                  571868330
# 1    571864735   29   X    X  ...  57186-11                  571868740
# 2   5718610227   29   X    X  ...  57186-10                  571868852
# ...

# %%
pd.read_csv("data/887477-EMDP.csv", encoding="UTF-8")
# Out:
#      机型     制造序列号    机号    参考类型    指令类型      件号                序号  章节号 非计划  \
# 0   73C  73C02581  2938  DE      CC      887477  MX-543639          29
# 1   73C  73C02557  2937  DE      CC      887477  MX-543639          29   X
# 2   73C  73C02859  2982  DE      CC      887477  MX-492433          29   X
# 3   73C  73C02811  2970  NRC     CC      887477  MX652408           29   X
# 4   73N  73N01033  2158  DE      CC      887477  MX621721           29   X
# 5   73N  73N04159  1902  DE      CC      887477  MX760495           29   X
# 6   73N  73N05384  1433  DE      CC      887477  MX785131           29   X
# 7   73N  73N04281  1559  DE      CC      887477  MX763411           29   X
# 8   73N  73N00551  5089  DE      CC      887477  MX621721           29   X
# 9   73N  73N00230  5091  DE      CC      887477  MX620435           29   X
# 10  73N  73N00551  5089  DE      CC      887477  MX-543639          29   X
# 11  73N  73N00260  5092  DE      CC      887477  MX610633A          29   X
# ...

# %%
data = emdp[emdp['部件装上使用小时数'] == "00:00"]
data
# Out:
#       机型     制造序列号        机号    参考类型    指令类型                        件号  \
# 1    73C  73C02543  2990      DE      CC      57186-10
# 2    73C  73C02859  2982      DE      CC      57186-10
# 3    73C  73C02557  2937      DE      CC      57186-10
# 4    73C  73C02342  2579      DE      CC      57186-10
# 5    73C  73C02811  2970      DE      CC      57186-10
# 6    73C  73C02859  2982      DE      CC      57186-10
# 7    73C  73C02939  2989      DE      CC      57186-10
# 8    73C  73C02859  2982      DE      CC      57186-10
# 9    73C  73C02922  2987      DE      CC      57186-10
# 13   73C  73C02811  2970      DE      CC      57186-10
# 14   73C  73C02342  2579      DE      CC      57186-10
# 15   73C  73C01866  2960      DE      CC      57186-10
# 18   73C  73C02581  2938      NRC     CC      57186-10
# 19   73C  73C02782  2965      NRC     CC      57186-10
# 20   73C  73C02793  2967      NRC     CC      57186-10
# 22   73C  73C02922  2987      NRC     CC      57186-10
# ...

# %%
data.loc[data['件号']=='887477                  ']
# Out:
#       机型     制造序列号        机号    参考类型    指令类型                        件号  \
# 236  73N  73N04159  1902      DE      CC      887477
# 237  73N  73N05384  1433      DE      CC      887477
# 238  73N  73N04281  1559      DE      CC      887477
# 239  73N  73N00551  5089      DE      CC      887477
# 241  73N  73N00551  5089      DE      CC      887477
# 248  73N  73N00548  5083      DE      CC      887477
# 250  73N  73N00477  5080      DE      CC      887477
# 252  73N  73N04209  1903      DE      CC      887477
# 255  73N  73N00163  5061      DE      CC      887477
# 258  73N  73N00551  5089      DE      CC      887477
# 259  73N  73N00577  5090      DE      CC      887477
# 263  73N  73N00587  5082      DE      CC      887477
# 266  73N  73N00230  5091      NRC     CC      887477
# 267  73N  73N00230  5091      NRC     CC      887477
# 272  73N  73N00577  5090      NRC     CC      887477
# 273  73N  73N04159  1902      NRC     CC      887477
# ...

# %%
data_1["IsPlanned"] = data_1["非计划"] == "X"
data_1 = data_1.loc[data_1["IsPlanned"] == False, ]
data_1['部件装上使用小时数']
# Out:
# C:\Users\shuangyang.luo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# 0      22314:22
# 8         00:00
# 13        00:00
# 15        00:00
# 18        00:00
# 21     29806:11
# 25        00:00
# 31        00:00
# 35        00:00
# 37        00:00
# 53        00:00
# 61        00:00
# 74        00:00
# 77        00:00
# 97     14886:45
# 110       00:00
# 130       00:00
# 136       00:00
# 149       00:00
# 154       00:00
# 160       00:00
# 167    17977:39
# 176       00:00
# 193       45:06
# 206    32535:18
# 211    20702:28
# 218       00:00
# Name: 部件装上使用小时数, dtype: object

# %%
pd.read_csv("data/887477-EMDP.csv", encoding="UTF-8")
# Out:
#      机型     制造序列号    机号    参考类型    指令类型      件号                序号  章节号 非计划  \
# 0   73C  73C02581  2938  DE      CC      887477  MX-543639          29
# 1   73C  73C02557  2937  DE      CC      887477  MX-543639          29   X
# 2   73C  73C02859  2982  DE      CC      887477  MX-492433          29   X
# 3   73C  73C02811  2970  NRC     CC      887477  MX652408           29   X
# 4   73N  73N01033  2158  DE      CC      887477  MX621721           29   X
# 5   73N  73N04159  1902  DE      CC      887477  MX760495           29   X
# 6   73N  73N05384  1433  DE      CC      887477  MX785131           29   X
# 7   73N  73N04281  1559  DE      CC      887477  MX763411           29   X
# 8   73N  73N00551  5089  DE      CC      887477  MX621721           29   X
# 9   73N  73N00230  5091  DE      CC      887477  MX620435           29   X
# 10  73N  73N00551  5089  DE      CC      887477  MX-543639          29   X
# 11  73N  73N00260  5092  DE      CC      887477  MX610633A          29   X
# ...

# %%
pd.read_excel("data/887477 EMDP现装机.xlsx", encoding="UTF-8")
# Out:
#       R  Av             Cond     P/n        S/n        Alt.Tp  \
# 0     I   =  Interchangeable       S          =  Superceeding
# 1   NaN  IN               IN  887477  MX-537132           NaN
# 2   NaN  IN               IN  887477  MX-503088           NaN
# 3   NaN  IN               IN  887477   MX652408           NaN
# 4   NaN  IN               IN  887477   MX654112           NaN
# 5   NaN  IN               IN  887477  MX-543638           NaN
# 6   NaN  IN               IN  887477  MX-555477           NaN
# 7   NaN  IN               IN  887477  MX-543639           NaN
# 8   NaN  IN               IN  887477  MX-492433           NaN
# 9   NaN  IN               IN  887477  MX-492434           NaN
# 10  NaN  IN               IN  887477   MX621721           NaN
# 11  NaN  IN               IN  887477   MX621720           NaN
# 12  NaN  IN               IN  887477  MX615683A           NaN
# 13  NaN  IN               IN  887477   MX651675           NaN
# ...

# %%
pd.read_excel("data/887477（新版）.xlsx", encoding="UTF-8")
# Out:
#         件号         序号       收料日期          备注   修理厂家          拆件原因  \
# 0   887477  MX-537132 2018-09-29         NaN   武汉航达        EMDP漏油
# 1   887477  MX-537132 2017-01-16         NaN   武汉航达        EMDP漏油
# 2   887477  MX-543638 2016-07-26         NaN   武汉航达        EMDP漏油
# 3   887477  MX-555477 2018-09-21         NaN   武汉航达        EMDP漏油
# 4   887477  MX-555477 2009-12-25         NaN   武汉航达        EMDP漏油
# 5   887477   MX603630 2019-05-09         NaN   武汉航达        EMDP漏油
# 6   887477   MX603630 2018-12-13         NaN   武汉航达        EMDP漏油
# 7   887477   MX603630 2012-09-18         NaN    无记录           无记录
# 8   887477   MX603630 2009-05-28         NaN   武汉航达        EMDP漏油
# 9   887477   MX603630 2007-10-27         NaN   武汉航达        EMDP漏油
# 10  887477   MX603630 2006-11-10         NaN   武汉航达        EMDP漏油
# 11  887477  MX620435A 2016-06-02         NaN   武汉航达        EMDP漏油
# 12  887477  MX620435A 2015-04-22         NaN   武汉航达        EMDP漏油
# ...

# %%
import os
pa = os.getcwd() + os.path.sep + "..\\" + "data_csv\\541674-4.csv"
data1 = pd.read_csv(pa, encoding = "GB2312")
data1
# Out:
#       机型     制造序列号    机号    参考类型    指令类型                        件号  \
# 0    73C  73C02581  2938  DE      CC      541674-4
# 1    73C  73C02581  2938  DE      CC      541674-4
# 2    73C  73C02581  2938  DE      CC      541674-4
# 3    73C  73C01866  2960  DE      CC      541674-4
# 4    73C  73C01866  2960  DE      CC      541674-4
# 5    73C  73C01866  2960  DE      CC      541674-4
# 6    73C  73C02543  2990  DE      CC      541674-4
# 7    73C  73C02859  2982  DE      CC      541674-4
# 8    73C  73C02543  2990  DE      CC      541674-4
# 9    73C  73C02939  2989  DE      CC      541674-4
# 10   73C  73C02782  2965  DE      CC      541674-4
# 11   73C  73C02811  2970  DE      CC      541674-4
# 12   73C  73C02859  2982  DE      CC      541674-4
# 13   73C  73C02859  2982  DE      CC      541674-4
# 14   73C  73C02543  2990  DE      CC      541674-4
# 15   73C  73C02922  2987  DE      CC      541674-4
# 16   73C  73C01866  2960  DE      CC      541674-4
# ...
