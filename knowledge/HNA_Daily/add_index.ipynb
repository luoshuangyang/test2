# %% [markdown]
# 添加index（随日期变化）

# %%
import pandas as pd
import numpy as np

# %%
M=pd.read_csv('空调数据采集8.3-8.4.csv',encoding = "GB18030",engine='python')
M
# Out:
#                    日期    地点   飞机号       机型  环境温度(℃)  左边CONT CABIN DUCT  \
# 0    2019-08-04 09:43   XIY  1101  737-800       24                  4
# 1    2019-08-04 09:41   XIY  1482  737-800       24                  5
# 2    2019-08-04 09:11   MIG  6809  737-800       26                  5
# 3    2019-08-04 09:00   FOC  7105  737-800       28                  3
# 4    2019-08-04 08:36   HAK  5521  737-800       27                  4
# 5    2019-08-04 08:35   HAK  5735  737-800       27                  3
# 6    2019-08-04 08:11   XMN  5480  737-800       29                  9
# 7    2019-08-04 08:11   XMN  6062  737-800       29                  9
# 8    2019-08-04 08:10   XMN  1501  737-800       28                  2
# 9    2019-08-04 08:10   XMM  5636  737-800       29                  8
# 10   2019-08-04 08:06   MIG  5409  737-800       26                  4
# 11   2019-08-04 08:03   KMG  7992  737-800       23                  5
# ...

# %%
M[u'日期'].str.split(' ')
# Out:
# 0      [2019-08-04, 09:43]
# 1      [2019-08-04, 09:41]
# 2      [2019-08-04, 09:11]
# 3      [2019-08-04, 09:00]
# 4      [2019-08-04, 08:36]
# 5      [2019-08-04, 08:35]
# 6      [2019-08-04, 08:11]
# 7      [2019-08-04, 08:11]
# 8      [2019-08-04, 08:10]
# 9      [2019-08-04, 08:10]
# 10     [2019-08-04, 08:06]
# 11     [2019-08-04, 08:03]
# 12     [2019-08-04, 08:02]
# 13     [2019-08-04, 07:53]
# 14     [2019-08-04, 07:52]
# 15     [2019-08-04, 07:51]
# 16     [2019-08-04, 07:49]
# 17     [2019-08-04, 07:45]
# 18     [2019-08-04, 07:17]
# 19     [2019-08-04, 07:06]
# 20     [2019-08-04, 07:01]
# 21     [2019-08-04, 06:44]
# 22     [2019-08-04, 06:43]
# 23     [2019-08-04, 06:23]
# 24     [2019-08-04, 06:18]
# 25     [2019-08-04, 06:14]
# 26     [2019-08-04, 05:56]
# 27     [2019-08-04, 05:55]
# 28     [2019-08-04, 05:15]
# 29     [2019-08-04, 05:12]
#               ...
# 230    [2019-08-03, 03:53]
# 231    [2019-08-03, 03:41]
# 232    [2019-08-03, 03:40]
# ...

# %%
M[u'日期'].str.split(' ').replace('-','').str.get(0)
# Out:
# 0      2019-08-04
# 1      2019-08-04
# 2      2019-08-04
# 3      2019-08-04
# 4      2019-08-04
# 5      2019-08-04
# 6      2019-08-04
# 7      2019-08-04
# 8      2019-08-04
# 9      2019-08-04
# 10     2019-08-04
# 11     2019-08-04
# 12     2019-08-04
# 13     2019-08-04
# 14     2019-08-04
# 15     2019-08-04
# 16     2019-08-04
# 17     2019-08-04
# 18     2019-08-04
# 19     2019-08-04
# 20     2019-08-04
# 21     2019-08-04
# 22     2019-08-04
# 23     2019-08-04
# 24     2019-08-04
# 25     2019-08-04
# 26     2019-08-04
# 27     2019-08-04
# 28     2019-08-04
# 29     2019-08-04
#           ...
# 230    2019-08-03
# 231    2019-08-03
# 232    2019-08-03
# 233    2019-08-03
# 234    2019-08-03
# 235    2019-08-03
# 236    2019-08-03
# 237    2019-08-03
# 238    2019-08-03
# 239    2019-08-03
# 240    2019-08-03
# 241    2019-08-03
# 242    2019-08-03
# 243    2019-08-03
# 244    2019-08-03
# 245    2019-08-03
# 246    2019-08-03
# 247    2019-08-03
# 248    2019-08-03
# ...

# %%
d=list(M[u'日期'].str.split(' ').replace('-','').str.get(0))
d
# Out:
# ['2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
#  '2019-08-04',
# ...

# %%
N=M[u'日期'].str.split(' ').replace('-','').str.get(0).unique()
N
# Out:
# array(['2019-08-04', '2019-08-03'], dtype=object)

# %%
e=list(N)
e
# Out:
# ['2019-08-04', '2019-08-03']

# %%
r=sorted(e)
r
# Out:
# ['2019-08-03', '2019-08-04']

# %%
iii=[]
for i in range(len(d)):
    ii=r.index(d[i])+1
    iii.append(ii)
    
M['index']=iii
M['index']
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     2
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     2
# 28     2
# 29     2
#       ..
# 230    1
# 231    1
# 232    1
# 233    1
# 234    1
# 235    1
# 236    1
# 237    1
# 238    1
# 239    1
# 240    1
# 241    1
# 242    1
# 243    1
# 244    1
# 245    1
# 246    1
# 247    1
# 248    1
# 249    1
# 250    1
# 251    1
# 252    1
# 253    1
# 254    1
# 255    1
# 256    1
# 257    1
# 258    1
# 259    1
# Name: index, Length: 260, dtype: int64

# %%
M
# Out:
#                    日期    地点   飞机号       机型  环境温度(℃)  左边CONT CABIN DUCT  \
# 0    2019-08-04 09:43   XIY  1101  737-800       24                  4
# 1    2019-08-04 09:41   XIY  1482  737-800       24                  5
# 2    2019-08-04 09:11   MIG  6809  737-800       26                  5
# 3    2019-08-04 09:00   FOC  7105  737-800       28                  3
# 4    2019-08-04 08:36   HAK  5521  737-800       27                  4
# 5    2019-08-04 08:35   HAK  5735  737-800       27                  3
# 6    2019-08-04 08:11   XMN  5480  737-800       29                  9
# 7    2019-08-04 08:11   XMN  6062  737-800       29                  9
# 8    2019-08-04 08:10   XMN  1501  737-800       28                  2
# 9    2019-08-04 08:10   XMM  5636  737-800       29                  8
# 10   2019-08-04 08:06   MIG  5409  737-800       26                  4
# 11   2019-08-04 08:03   KMG  7992  737-800       23                  5
# ...

# %%
#M.insert(14,'index',0)
