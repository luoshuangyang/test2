# %% [markdown]
# ### 4-6 月数据格式修改

# %%
import pandas as pd
import numpy as np

# %%
A=pd.read_csv("AirConditionDaily_csv/737_Apr-Jun.csv", encoding = "GB18030")
A
# Out:
#                      日期    地点   飞机号       机型  环境温度(℃)  左边CONT CABIN DUCT  \
# 0      2019-06-21 09:45   KMG  5409  737-800       20                  4
# 1      2019-06-21 08:50   HAK  1785  737-800       30                  6
# 2      2019-06-21 08:35   KMG  6015  737-800       20                  4
# 3      2019-06-21 08:30   FOC  7113  737-800       30                  8
# 4      2019-06-21 08:29   FOC  7113  737-800       30                  8
# 5      2019-06-21 08:16   TYN  1728  737-800       25                  4
# 6      2019-06-21 07:51   URC  7198  737-800       22                  4
# 7      2019-06-21 07:31   XMN  5480  737-800       26                  6
# 8      2019-06-21 07:31   XMN  5479  737-800       28                  6
# 9      2019-06-21 07:30   XMN  7399  737-800       28                  4
# 10     2019-06-21 07:24   HHA  5405  737-800       31                  6
# 11     2019-06-21 06:53   HHA  1347  737-800       30                  7
# ...

# %%
A.drop(u'左温差', axis=1, inplace=True)
A.drop(u'右温差', axis=1, inplace=True)
A.drop('Fail', axis=1, inplace=True)
#指定位置插入一列数据
#A[u'右边L PACK']=0
#col_name = A.columns.tolist()
#col_name.insert(col_name.index(u'右边L PACK')+1,u'右边SUPPLY DUCT')
#A.reindex(columns=col_name)

A.insert(10,u'右边SUPPLY DUCT',0)
A.insert(7,u'左边SUPPLY DUCT',0)
A.rename(columns={u'更换部件':u'换件'},inplace=True)
A[u'执行反吹左侧 (机器输出结果)']=np.NaN
A[u'执行反吹右侧 (机器输出结果)']=np.NaN
A
# Out:
#                      日期    地点   飞机号       机型  环境温度(℃)  左边CONT CABIN DUCT  \
# 0      2019-06-21 09:45   KMG  5409  737-800       20                  4
# 1      2019-06-21 08:50   HAK  1785  737-800       30                  6
# 2      2019-06-21 08:35   KMG  6015  737-800       20                  4
# 3      2019-06-21 08:30   FOC  7113  737-800       30                  8
# 4      2019-06-21 08:29   FOC  7113  737-800       30                  8
# 5      2019-06-21 08:16   TYN  1728  737-800       25                  4
# 6      2019-06-21 07:51   URC  7198  737-800       22                  4
# 7      2019-06-21 07:31   XMN  5480  737-800       26                  6
# 8      2019-06-21 07:31   XMN  5479  737-800       28                  6
# 9      2019-06-21 07:30   XMN  7399  737-800       28                  4
# 10     2019-06-21 07:24   HHA  5405  737-800       31                  6
# 11     2019-06-21 06:53   HHA  1347  737-800       30                  7
# ...

# %%
A.to_csv("_737_Apr-Jun.csv",index=False,encoding = "GB18030")

# %%
pd.read_csv("_737_Apr-Jun.csv", encoding = "GB18030")
# Out:
#                      日期    地点   飞机号       机型  环境温度(℃)  左边CONT CABIN DUCT  \
# 0      2019-06-21 09:45   KMG  5409  737-800       20                  4
# 1      2019-06-21 08:50   HAK  1785  737-800       30                  6
# 2      2019-06-21 08:35   KMG  6015  737-800       20                  4
# 3      2019-06-21 08:30   FOC  7113  737-800       30                  8
# 4      2019-06-21 08:29   FOC  7113  737-800       30                  8
# 5      2019-06-21 08:16   TYN  1728  737-800       25                  4
# 6      2019-06-21 07:51   URC  7198  737-800       22                  4
# 7      2019-06-21 07:31   XMN  5480  737-800       26                  6
# 8      2019-06-21 07:31   XMN  5479  737-800       28                  6
# 9      2019-06-21 07:30   XMN  7399  737-800       28                  4
# 10     2019-06-21 07:24   HHA  5405  737-800       31                  6
# 11     2019-06-21 06:53   HHA  1347  737-800       30                  7
# ...

# %%
import pandas as pd
import numpy as np
pd.read_csv('20190811_zuixin', encoding = "GB18030")
# Out:
# C:\Users\shuangyang.luo\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   This is separate from the ipykernel package so we can avoid doing imports until
#     ,Unnamed: 0,日期,地点,飞机号,机型,环境温度(℃),左边CONT CABIN DUCT,左边L PACK,左边SUPPLY DUCT,右边FWD DUCT,右边AFT DUCT,右边L PACK,右边SUPPLY DUCT,执行反吹左侧,执行反吹右侧,换件,左温差(前天),执行反吹左侧(前天),右温差(前天),执行反吹右侧(前天),左温差(昨天),执行反吹左侧(昨天),右温差(昨天),执行反吹右侧(昨天),执行反吹左侧 (机器输出结果),执行反吹右侧 (机器输出结果)
# 0    0,0,2019-08-11 17:53,DLC,1131,737-800,27,5,36,...
# 1    1,1,2019-08-11 15:48,HHA,5135,737-800,29,4,34,...
# 2    2,2,2019-08-11 15:04,ZGC,6060,737-800,15,6,24,...
# 3    3,3,2019-08-11 15:03,ZGC,7398,737-800,15,6,24,...
# 4    4,4,2019-08-11 15:03,ZGC,5478,737-800,16,6,22,...
# 5    5,5,2019-08-11 09:11,绵阳,5732,737-800,29,2,30,0...
# 6    6,6,2019-08-11 08:29,SYX,1496,737-800,30,4,34,...
# 7    7,7,2019-08-11 08:20,URC,1570,737-800,20,2,26,...
# ...
